# %% [markdown]
# # Papers Past Genre Classification
# # Notebook 5: Binary Classification
# ---
#
# This notebook trains and evaluates a number of classification models and feature sets using a binary classification approach where the target genre is given the outcome '1' and all other genres '0'. Each combination of genre and feature set is evaluated. The loaded dataset is the output of Notebook 3: Linguistic Feature Extraction. A dataframe of the metrics for all combinations is returned and exported as a csv file for further analysis.

# %%
import pandas as pd
import numpy as np
import pickle

from imblearn.over_sampling import RandomOverSampler
from collections import Counter

# Features
from sklearn.preprocessing import LabelEncoder
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import TruncatedSVD
from sklearn.preprocessing import label_binarize
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler

# Classifiers
from sklearn.dummy import DummyClassifier
from sklearn.linear_model import SGDClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.multiclass import OneVsRestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC

# Metrics/Evaluation
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score,
from sklearn.metrics import roc_curve, auc, roc_auc_score, confusion_matrix
from sklearn.metrics import RocCurveDisplay
from sklearn.metrics import PrecisionRecallDisplay
from sklearn.metrics import average_precision_score, precision_recall_curve
from sklearn.metrics import plot_precision_recall_curve
from scipy import interp
from itertools import cycle

# Plotting
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('darkgrid')

from datetime import date
from datetime import datetime

# %%
filepath = '20220113_PP_3518articles_withfeatures.pkl'
features_df = pd.read_pickle(filepath)

# %%
len(features_df)
# Out:
# 3518

# %%
# View the distribution of the genres
(features_df['genre'].value_counts() / len(features_df)).sort_values(ascending=False)
# Out:
# Report            0.284537
# News              0.163729
# Notice            0.162308
# Opinion           0.138999
# Feature           0.048891
# LetterToEditor    0.047754
# Results           0.041217
# FamilyNotice      0.029278
# Fiction           0.020182
# Advertisement     0.018761
# Review            0.018476
# Poetry            0.009665
# Obituary          0.009096
# Speech            0.007106
# Name: genre, dtype: float64

# %%
# List of genres
genre_list = ["Report", 
              "News", 
              "Notice", 
              "Opinion", 
              "Feature", 
              "LetterToEditor", 
              "Results", 
              "FamilyNotice", 
              "Advertisement", 
              "Fiction", 
              "Review", 
              "Obituary", 
              "Poetry", 
              "Speech"]

# Dictionary of feature groups
feature_dict = {'pos_freq_penn': ["nnps_freq", "vb_freq", "nn_freq", 
                                   "jj_freq", "cd_freq", "prp_freq", 
                                   "rb_freq", "cc_freq", "nnp_freq", 
                                   "vbd_freq", "vbz_freq", "stopword_freq"],
                'pos_freq_univ': ["propn_freq", "verb_freq", "noun_freq", 
                                   "adj_freq", "nums_freq", "pron_freq", 
                                   "stopword_freq"],
                'pos_freq_combo': ["nnps_freq", "vb_freq", "nn_freq", 
                                    "jj_freq", "cd_freq", "prp_freq", 
                                    "rb_freq", "cc_freq", "nnp_freq", 
                                    "vbd_freq", "vbz_freq", "propn_freq", 
                                    "verb_freq", "noun_freq", "adj_freq", 
                                    "nums_freq", "pron_freq", "stopword_freq"],
                'line_offsets': ["avg_line_offset", "max_line_offset"],
                'line_widths': ["avg_line_width", "min_line_width", 
                                "max_line_width", "line_width_range"],
                'syllable_freq': ["polysyll_freq", "monosyll_freq"],
                'tf_idf': ["tf_idf_sum"],
                'text_stats': ["sentence_count", "word_count", 
                               "avg_word_length", "char_count"],
                'all_features': ["propn_freq", "verb_freq", "noun_freq", 
                                 "adj_freq", "nums_freq", "pron_freq", 
                                 "nnps_freq", "vb_freq", "nn_freq", 
                                 "jj_freq", "cd_freq", "prp_freq", "rb_freq", 
                                 "cc_freq", "nnp_freq", "vbd_freq", "vbz_freq", 
                                 "stopword_freq", "avg_line_offset", "max_line_offset", 
                                 "avg_line_width", "min_line_width", "max_line_width", 
                                 "line_width_range", "polysyll_freq", "monosyll_freq", 
                                 "sentence_count", "word_count", "avg_word_length", 
                                 "char_count", "tf_idf_sum"],
                'all_features_excl_penn': ["propn_freq", "verb_freq", "noun_freq", 
                                           "adj_freq", "nums_freq", "pron_freq", 
                                           "stopword_freq", "avg_line_offset", 
                                           "max_line_offset", "avg_line_width", 
                                           "min_line_width", "max_line_width", 
                                           "line_width_range", "polysyll_freq", 
                                           "monosyll_freq", "sentence_count", "word_count", 
                                           "avg_word_length", "char_count", "tf_idf_sum"],
                'all_features_excl_univ': ["nnps_freq", "vb_freq", "nn_freq", 
                                           "jj_freq", "cd_freq", "prp_freq", 
                                           "rb_freq", "cc_freq", "nnp_freq", 
                                           "vbd_freq", "vbz_freq", "stopword_freq", 
                                           "avg_line_offset", "max_line_offset", 
                                           "avg_line_width", "min_line_width", 
                                           "max_line_width", "line_width_range", 
                                           "polysyll_freq", "monosyll_freq", "sentence_count", 
                                           "word_count", "avg_word_length", "char_count", 
                                           "tf_idf_sum"],
                'all_features_excl_tfidf': ["nnps_freq", "vb_freq", "nn_freq", 
                                            "jj_freq", "cd_freq", "prp_freq", 
                                            "rb_freq", "cc_freq", "nnp_freq", 
                                            "vbd_freq", "vbz_freq", "stopword_freq", 
                                            "avg_line_offset", "max_line_offset", 
                                            "avg_line_width", "min_line_width", "max_line_width", 
                                            "line_width_range", "polysyll_freq", "monosyll_freq", 
                                            "sentence_count", "word_count", "avg_word_length", 
                                            "char_count"]
               }

# %%
# Dictionary of models

model_dict = {'Dummy' : DummyClassifier(random_state=3),
              'Stochastic Gradient Descent' : SGDClassifier(random_state=3, loss='log', class_weight="balanced"),
              'Random Forest': RandomForestClassifier(class_weight="balanced", random_state=3),
              'Decision Tree': DecisionTreeClassifier(class_weight="balanced", random_state=3),
              'AdaBoost': AdaBoostClassifier(random_state=3),
              'GradientBoosting': GradientBoostingClassifier(n_estimators=100, learning_rate=1.0,max_depth=1, random_state=3),
              'Gaussian Naive Bayes': GaussianNB(),
              'K Nearest Neighbor': KNeighborsClassifier(), 
              'Logistic Regression': LogisticRegression(class_weight="balanced"),
              'Support Vector Machine': SVC(kernel='rbf', class_weight="balanced", random_state=3)}

# %%
# Preliminary model evaluation using default parameters
# Code reference: https://medium.com/@robert.salgado/multiclass-text-classification-from-start-to-finish-f616a8642538

# Function to get the scores for each model in a df
def model_score_df(model_dict, X_train, X_test, y_train, y_test, genre, feature_set):
    """
    Given a dictionary of scikit learn models, 
    return and a dataframe of metrics ranked by 
    best AUROC score. 
    
    Option to print an AUROC chart for each model, feature set,
    and genre combination if required.
    """
    genre_list = []
    feature_set_list = []
    model_name = [] 
    ac_score_list = []
    p_score_list = []
    r_score_list = []
    f1_score_list = []
    auroc_score_list = []
    
    for k,v in model_dict.items():   
        genre_list.append(genre)
        feature_set_list.append(feature_set)
        model_name.append(k)
        pipe = make_pipeline(StandardScaler(), v) # data is scaled
        pipe.fit(X_train, y_train)
        y_pred = pipe.predict(X_test)
        ac_score_list.append(accuracy_score(y_test, y_pred))
        p_score_list.append(precision_score(y_test, y_pred, average = 'binary'))
        r_score_list.append(recall_score(y_test, y_pred, average = 'binary'))
        f1_score_list.append(f1_score(y_test, y_pred, average = 'binary'))
        auroc_score_list.append(roc_auc_score(y_test, y_pred))
        model_comparison_df = pd.DataFrame([genre_list, 
                                            feature_set_list, 
                                            model_name, 
                                            ac_score_list, 
                                            p_score_list, 
                                            r_score_list, 
                                            f1_score_list, 
                                            auroc_score_list]).T
        model_comparison_df.columns = ['genre', 
                                       'feature_set', 
                                       'model_name', 
                                       'accuracy_score', 
                                       'precision_score', 
                                       'recall_score', 
                                       'f1_score', 
                                       'auroc_score']
        model_comparison_df = model_comparison_df.sort_values(by='auroc_score', ascending=False)
#         RocCurveDisplay.from_predictions(y_test, y_pred)
#         plt.title(f"AUROC: {k}")
#         plt.show()
    
    return model_comparison_df

# %%
def genres_binary(df, genre_list, feature_dict, model_dict):
    """
    Given a list of genres and dictionaries
    of features and models, train and test binary classification
    models for each combination of genre and features and 
    return the dataframe of results.
    """
    dataframes = []
    
    # Append "binary_class" to each feature dictionary
    for k, v in feature_dict.items():
        v.append("binary_class")
    
    for genre in genre_list:
        temp_df = df  # Resets the dataframe for each run of the loop
        temp_df['binary_class'] = np.where(temp_df['genre']== genre, 1, 0)
        
        for k, v in feature_dict.items():
            model_df = temp_df.filter(v, axis=1)
            
            # Extract the explanatory variables in X and the target variable in y
            y = model_df.binary_class.copy()
            X = model_df.drop(["binary_class"], axis=1)
            
            #Train test split with stratified sampling for evaluation
            X_train, X_test, y_train, y_test = train_test_split(X, 
                                                                y, 
                                                                test_size = .3, 
                                                                shuffle = True, 
                                                                stratify = y, 
                                                                random_state = 3)
            
            model_results = model_score_df(model_dict, X_train, X_test, y_train, y_test, genre, k) 
            dataframes.append(model_results)
            # print(model_results)
        
        del temp_df, y, X, model_df, X_train, X_test, y_train, y_test  # Clear the dataframes from memory before next loop
        
    results_df = pd.concat(dataframes)
    
    return results_df

# %%
results_df = genres_binary(features_df, genre_list, feature_dict, model_dict)
# Out:
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kst103\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
results_df = results_df.sort_values(by='auroc_score', ascending=False)
pd.set_option('display.max_rows', None)
display(results_df)
# Out:
#             genre              feature_set                   model_name  \
# 8          Poetry             all_features          Logistic Regression
# 8          Poetry   all_features_excl_univ          Logistic Regression
# 8         Fiction             all_features          Logistic Regression
# 1         Fiction  all_features_excl_tfidf  Stochastic Gradient Descent
# 1         Fiction   all_features_excl_penn  Stochastic Gradient Descent
# 8         Fiction  all_features_excl_tfidf          Logistic Regression
# 8         Fiction   all_features_excl_univ          Logistic Regression
# 9    FamilyNotice            pos_freq_univ       Support Vector Machine
# 6         Fiction   all_features_excl_penn         Gaussian Naive Bayes
# 8          Poetry            pos_freq_univ          Logistic Regression
# 8          Poetry            pos_freq_penn          Logistic Regression
# 9         Fiction             all_features       Support Vector Machine
# 9         Fiction   all_features_excl_penn       Support Vector Machine
# 8         Fiction   all_features_excl_penn          Logistic Regression
# 9          Speech            pos_freq_penn       Support Vector Machine
# 9         Fiction           pos_freq_combo       Support Vector Machine
# 6         Fiction  all_features_excl_tfidf         Gaussian Naive Bayes
# 6         Fiction   all_features_excl_univ         Gaussian Naive Bayes
# 8          Notice           pos_freq_combo          Logistic Regression
# 1          Speech             all_features  Stochastic Gradient Descent
# 9         Fiction            pos_freq_univ       Support Vector Machine
# 6         Fiction             all_features         Gaussian Naive Bayes
# 8         Fiction           pos_freq_combo          Logistic Regression
# 8          Speech             all_features          Logistic Regression
# 8    FamilyNotice             all_features          Logistic Regression
# 8          Speech   all_features_excl_univ          Logistic Regression
# 1         Fiction             all_features  Stochastic Gradient Descent
# 8          Speech  all_features_excl_tfidf          Logistic Regression
# 9         Fiction  all_features_excl_tfidf       Support Vector Machine
# 8         Fiction            pos_freq_penn          Logistic Regression
# 8          Poetry   all_features_excl_penn          Logistic Regression
# 8    FamilyNotice  all_features_excl_tfidf          Logistic Regression
# 8    FamilyNotice   all_features_excl_univ          Logistic Regression
# 1    FamilyNotice             all_features  Stochastic Gradient Descent
# 1    FamilyNotice  all_features_excl_tfidf  Stochastic Gradient Descent
# 9          Notice   all_features_excl_penn       Support Vector Machine
# 8          Poetry  all_features_excl_tfidf          Logistic Regression
# 8         Fiction            pos_freq_univ          Logistic Regression
# 6          Poetry  all_features_excl_tfidf         Gaussian Naive Bayes
# 1         Fiction           pos_freq_combo  Stochastic Gradient Descent
# 8    FamilyNotice           pos_freq_combo          Logistic Regression
# 1    FamilyNotice   all_features_excl_univ  Stochastic Gradient Descent
# 9          Notice             all_features       Support Vector Machine
# 8          Notice            pos_freq_penn          Logistic Regression
# 9  LetterToEditor             all_features       Support Vector Machine
# 1    FamilyNotice   all_features_excl_penn  Stochastic Gradient Descent
# 9          Notice   all_features_excl_univ       Support Vector Machine
# 8          Poetry           pos_freq_combo          Logistic Regression
# 8          Notice  all_features_excl_tfidf          Logistic Regression
# 8          Notice   all_features_excl_univ          Logistic Regression
# 9          Notice           pos_freq_combo       Support Vector Machine
# 8        Obituary           pos_freq_combo          Logistic Regression
# 1          Speech   all_features_excl_penn  Stochastic Gradient Descent
# 1          Speech   all_features_excl_univ  Stochastic Gradient Descent
# 8    FamilyNotice   all_features_excl_penn          Logistic Regression
# 6         Fiction            pos_freq_univ         Gaussian Naive Bayes
# 8          Notice             all_features          Logistic Regression
# 9         Fiction            pos_freq_penn       Support Vector Machine
# 6    FamilyNotice   all_features_excl_univ         Gaussian Naive Bayes
# 9          Notice            pos_freq_penn       Support Vector Machine
# 1    FamilyNotice           pos_freq_combo  Stochastic Gradient Descent
# 1         Fiction            pos_freq_univ  Stochastic Gradient Descent
# 8    FamilyNotice            pos_freq_univ          Logistic Regression
# 9          Notice  all_features_excl_tfidf       Support Vector Machine
# 6    FamilyNotice  all_features_excl_tfidf         Gaussian Naive Bayes
# 9  LetterToEditor   all_features_excl_univ       Support Vector Machine
# 1          Poetry           pos_freq_combo  Stochastic Gradient Descent
# 9    FamilyNotice   all_features_excl_univ       Support Vector Machine
# 1    FamilyNotice            pos_freq_univ  Stochastic Gradient Descent
# 9    FamilyNotice  all_features_excl_tfidf       Support Vector Machine
# 8          Notice   all_features_excl_penn          Logistic Regression
# 9    FamilyNotice   all_features_excl_penn       Support Vector Machine
# 8          Review   all_features_excl_univ          Logistic Regression
# 1          Notice   all_features_excl_univ  Stochastic Gradient Descent
# 1          Notice  all_features_excl_tfidf  Stochastic Gradient Descent
# 9         Fiction   all_features_excl_univ       Support Vector Machine
# 8          Review  all_features_excl_tfidf          Logistic Regression
# 8          Notice            pos_freq_univ          Logistic Regression
# 6          Notice             all_features         Gaussian Naive Bayes
# 1         Fiction            pos_freq_penn  Stochastic Gradient Descent
# 8  LetterToEditor             all_features          Logistic Regression
# 8          Speech   all_features_excl_penn          Logistic Regression
# 9          Review            pos_freq_penn       Support Vector Machine
# 9  LetterToEditor  all_features_excl_tfidf       Support Vector Machine
# 6    FamilyNotice             all_features         Gaussian Naive Bayes
# 6          Notice           pos_freq_combo         Gaussian Naive Bayes
# 9          Notice            pos_freq_univ       Support Vector Machine
# 1          Notice             all_features  Stochastic Gradient Descent
# 8    FamilyNotice            pos_freq_penn          Logistic Regression
# 6          Speech  all_features_excl_tfidf         Gaussian Naive Bayes
# 6          Notice   all_features_excl_penn         Gaussian Naive Bayes
# 6          Speech   all_features_excl_univ         Gaussian Naive Bayes
# 6          Notice  all_features_excl_tfidf         Gaussian Naive Bayes
# 9  LetterToEditor   all_features_excl_penn       Support Vector Machine
# 9         Results   all_features_excl_penn       Support Vector Machine
# 9         Results             all_features       Support Vector Machine
# 1          Notice            pos_freq_univ  Stochastic Gradient Descent
# 6          Notice            pos_freq_penn         Gaussian Naive Bayes
# 8  LetterToEditor   all_features_excl_univ          Logistic Regression
# 9            News   all_features_excl_univ       Support Vector Machine
# 8          Review           pos_freq_combo          Logistic Regression
# 6          Notice   all_features_excl_univ         Gaussian Naive Bayes
# 8        Obituary            pos_freq_penn          Logistic Regression
# 1          Notice           pos_freq_combo  Stochastic Gradient Descent
# 8  LetterToEditor   all_features_excl_penn          Logistic Regression
# 6         Fiction            pos_freq_penn         Gaussian Naive Bayes
# 9         Fiction               text_stats       Support Vector Machine
# 6    FamilyNotice   all_features_excl_penn         Gaussian Naive Bayes
# 8         Results             all_features          Logistic Regression
# 4         Fiction             all_features                     AdaBoost
# 9          Speech           pos_freq_combo       Support Vector Machine
# 8          Review            pos_freq_penn          Logistic Regression
# 9            News   all_features_excl_penn       Support Vector Machine
# 4         Fiction   all_features_excl_penn                     AdaBoost
# 8          Review             all_features          Logistic Regression
# 9            News             all_features       Support Vector Machine
# 1         Fiction   all_features_excl_univ  Stochastic Gradient Descent
# 1          Notice   all_features_excl_penn  Stochastic Gradient Descent
# 8          Poetry            syllable_freq          Logistic Regression
# 9            News  all_features_excl_tfidf       Support Vector Machine
# 9        Obituary            pos_freq_penn       Support Vector Machine
# 6          Speech            pos_freq_univ         Gaussian Naive Bayes
# 9    FamilyNotice             all_features       Support Vector Machine
# 6         Fiction           pos_freq_combo         Gaussian Naive Bayes
# 1          Notice            pos_freq_penn  Stochastic Gradient Descent
# 6          Notice            pos_freq_univ         Gaussian Naive Bayes
# 1         Fiction               text_stats  Stochastic Gradient Descent
# 8  LetterToEditor  all_features_excl_tfidf          Logistic Regression
# 9          Review           pos_freq_combo       Support Vector Machine
# 1          Poetry   all_features_excl_penn  Stochastic Gradient Descent
# 8         Results   all_features_excl_univ          Logistic Regression
# 1          Poetry             all_features  Stochastic Gradient Descent
# 8         Results  all_features_excl_tfidf          Logistic Regression
# 6          Poetry   all_features_excl_univ         Gaussian Naive Bayes
# 8          Speech               text_stats          Logistic Regression
# 8         Feature  all_features_excl_tfidf          Logistic Regression
# 5    FamilyNotice            pos_freq_penn             GradientBoosting
# 1          Poetry   all_features_excl_univ  Stochastic Gradient Descent
# 1          Poetry  all_features_excl_tfidf  Stochastic Gradient Descent
# 1         Results            pos_freq_univ  Stochastic Gradient Descent
# 9    FamilyNotice           pos_freq_combo       Support Vector Machine
# 1          Speech  all_features_excl_tfidf  Stochastic Gradient Descent
# 9         Opinion  all_features_excl_tfidf       Support Vector Machine
# 4          Notice             all_features                     AdaBoost
# 9         Opinion             all_features       Support Vector Machine
# 1          Speech           pos_freq_combo  Stochastic Gradient Descent
# 8         Results   all_features_excl_penn          Logistic Regression
# 9         Opinion   all_features_excl_univ       Support Vector Machine
# 6          Poetry             all_features         Gaussian Naive Bayes
# 9         Results            pos_freq_penn       Support Vector Machine
# 6        Obituary           pos_freq_combo         Gaussian Naive Bayes
# 1          Poetry            pos_freq_univ  Stochastic Gradient Descent
# 8         Fiction               text_stats          Logistic Regression
# 8         Feature             all_features          Logistic Regression
# 8         Opinion   all_features_excl_univ          Logistic Regression
# 9         Fiction              line_widths       Support Vector Machine
# 9         Feature  all_features_excl_tfidf       Support Vector Machine
# 9         Results   all_features_excl_univ       Support Vector Machine
# 8         Opinion             all_features          Logistic Regression
# 1          Poetry            pos_freq_penn  Stochastic Gradient Descent
# 8            News             all_features          Logistic Regression
# 9         Results  all_features_excl_tfidf       Support Vector Machine
# 1            News             all_features  Stochastic Gradient Descent
# 8         Results           pos_freq_combo          Logistic Regression
# 9         Feature            pos_freq_penn       Support Vector Machine
# 9         Feature             all_features       Support Vector Machine
# 3         Fiction   all_features_excl_penn                Decision Tree
# 8         Results            pos_freq_univ          Logistic Regression
# 9         Opinion   all_features_excl_penn       Support Vector Machine
# 8  LetterToEditor           pos_freq_combo          Logistic Regression
# 9    FamilyNotice             line_offsets       Support Vector Machine
# 8         Feature   all_features_excl_univ          Logistic Regression
# 4         Fiction  all_features_excl_tfidf                     AdaBoost
# 3         Fiction           pos_freq_combo                Decision Tree
# 8         Results            pos_freq_penn          Logistic Regression
# 9         Feature   all_features_excl_univ       Support Vector Machine
# 3         Fiction             all_features                Decision Tree
# 9  LetterToEditor           pos_freq_combo       Support Vector Machine
# 9         Results            pos_freq_univ       Support Vector Machine
# 9    FamilyNotice            pos_freq_penn       Support Vector Machine
# 8         Opinion  all_features_excl_tfidf          Logistic Regression
# 6          Speech             all_features         Gaussian Naive Bayes
# 9         Feature           pos_freq_combo       Support Vector Machine
# 1         Results           pos_freq_combo  Stochastic Gradient Descent
# 9         Opinion           pos_freq_combo       Support Vector Machine
# 4          Notice  all_features_excl_tfidf                     AdaBoost
# 4          Notice   all_features_excl_univ                     AdaBoost
# 8         Feature           pos_freq_combo          Logistic Regression
# 9         Feature            pos_freq_univ       Support Vector Machine
# 9         Opinion            pos_freq_penn       Support Vector Machine
# 8         Opinion            pos_freq_penn          Logistic Regression
# 8   Advertisement           pos_freq_combo          Logistic Regression
# 8  LetterToEditor            pos_freq_univ          Logistic Regression
# 9          Speech               text_stats       Support Vector Machine
# 9          Review   all_features_excl_penn       Support Vector Machine
# 9    FamilyNotice               text_stats       Support Vector Machine
# 9          Review             all_features       Support Vector Machine
# 1            News  all_features_excl_tfidf  Stochastic Gradient Descent
# 8         Fiction              line_widths          Logistic Regression
# 1          Review   all_features_excl_univ  Stochastic Gradient Descent
# 8            News   all_features_excl_univ          Logistic Regression
# 8            News  all_features_excl_tfidf          Logistic Regression
# 1         Opinion   all_features_excl_univ  Stochastic Gradient Descent
# 8   Advertisement  all_features_excl_tfidf          Logistic Regression
# 6         Feature            pos_freq_penn         Gaussian Naive Bayes
# 8   Advertisement   all_features_excl_penn          Logistic Regression
# 1         Opinion             all_features  Stochastic Gradient Descent
# 8         Opinion           pos_freq_combo          Logistic Regression
# 1         Feature           pos_freq_combo  Stochastic Gradient Descent
# 8            News   all_features_excl_penn          Logistic Regression
# 6         Opinion  all_features_excl_tfidf         Gaussian Naive Bayes
# 1         Results  all_features_excl_tfidf  Stochastic Gradient Descent
# 6   Advertisement            pos_freq_penn         Gaussian Naive Bayes
# 6         Opinion   all_features_excl_univ         Gaussian Naive Bayes
# 1          Review  all_features_excl_tfidf  Stochastic Gradient Descent
# 6         Feature   all_features_excl_univ         Gaussian Naive Bayes
# 9         Results           pos_freq_combo       Support Vector Machine
# 6          Speech   all_features_excl_penn         Gaussian Naive Bayes
# 5         Fiction               text_stats             GradientBoosting
# 1            News   all_features_excl_univ  Stochastic Gradient Descent
# 9        Obituary           pos_freq_combo       Support Vector Machine
# 1         Feature            pos_freq_penn  Stochastic Gradient Descent
# 8         Opinion   all_features_excl_penn          Logistic Regression
# 8          Poetry              line_widths          Logistic Regression
# 1          Review             all_features  Stochastic Gradient Descent
# 6         Feature           pos_freq_combo         Gaussian Naive Bayes
# 9         Fiction            syllable_freq       Support Vector Machine
# 2         Fiction            pos_freq_penn                Random Forest
# 1         Results             all_features  Stochastic Gradient Descent
# 9   Advertisement  all_features_excl_tfidf       Support Vector Machine
# 8  LetterToEditor            pos_freq_penn          Logistic Regression
# 1          Poetry               text_stats  Stochastic Gradient Descent
# 6          Speech           pos_freq_combo         Gaussian Naive Bayes
# 4         Fiction   all_features_excl_univ                     AdaBoost
# 4         Fiction           pos_freq_combo                     AdaBoost
# 7         Fiction             all_features           K Nearest Neighbor
# 9         Opinion            pos_freq_univ       Support Vector Machine
# 8         Feature            pos_freq_penn          Logistic Regression
# 8   Advertisement            pos_freq_penn          Logistic Regression
# 5          Notice             all_features             GradientBoosting
# 6        Obituary            pos_freq_penn         Gaussian Naive Bayes
# 6  LetterToEditor             all_features         Gaussian Naive Bayes
# 1          Review            pos_freq_penn  Stochastic Gradient Descent
# 9         Feature   all_features_excl_penn       Support Vector Machine
# 9          Speech             all_features       Support Vector Machine
# 7         Fiction           pos_freq_combo           K Nearest Neighbor
# 8          Speech           pos_freq_combo          Logistic Regression
# 4         Fiction            pos_freq_univ                     AdaBoost
# 6    FamilyNotice            pos_freq_univ         Gaussian Naive Bayes
# 1         Feature            pos_freq_univ  Stochastic Gradient Descent
# 8          Review   all_features_excl_penn          Logistic Regression
# 9          Speech            pos_freq_univ       Support Vector Machine
# 8          Speech            pos_freq_penn          Logistic Regression
# 6         Opinion             all_features         Gaussian Naive Bayes
# 6  LetterToEditor  all_features_excl_tfidf         Gaussian Naive Bayes
# 7          Notice             all_features           K Nearest Neighbor
# 9          Review            pos_freq_univ       Support Vector Machine
# 6         Opinion            pos_freq_penn         Gaussian Naive Bayes
# 6         Feature  all_features_excl_tfidf         Gaussian Naive Bayes
# 6  LetterToEditor   all_features_excl_univ         Gaussian Naive Bayes
# 8   Advertisement             all_features          Logistic Regression
# 5          Notice  all_features_excl_tfidf             GradientBoosting
# 7          Notice   all_features_excl_penn           K Nearest Neighbor
# 1         Fiction            syllable_freq  Stochastic Gradient Descent
# 8         Opinion            pos_freq_univ          Logistic Regression
# 8         Feature            pos_freq_univ          Logistic Regression
# 1         Opinion  all_features_excl_tfidf  Stochastic Gradient Descent
# 8    FamilyNotice             line_offsets          Logistic Regression
# 1         Opinion            pos_freq_penn  Stochastic Gradient Descent
# 9            News            pos_freq_penn       Support Vector Machine
# 6         Opinion   all_features_excl_penn         Gaussian Naive Bayes
# 9          Report   all_features_excl_univ       Support Vector Machine
# 1  LetterToEditor             all_features  Stochastic Gradient Descent
# 6    FamilyNotice           pos_freq_combo         Gaussian Naive Bayes
# 6          Poetry   all_features_excl_penn         Gaussian Naive Bayes
# 6         Opinion           pos_freq_combo         Gaussian Naive Bayes
# 4          Notice   all_features_excl_penn                     AdaBoost
# 9            News           pos_freq_combo       Support Vector Machine
# 5          Notice   all_features_excl_univ             GradientBoosting
# 1   Advertisement   all_features_excl_univ  Stochastic Gradient Descent
# 6         Fiction               text_stats         Gaussian Naive Bayes
# 1         Results   all_features_excl_penn  Stochastic Gradient Descent
# 2          Notice  all_features_excl_tfidf                Random Forest
# 8         Feature   all_features_excl_penn          Logistic Regression
# 1          Poetry             line_offsets  Stochastic Gradient Descent
# 6         Feature             all_features         Gaussian Naive Bayes
# 9          Report             all_features       Support Vector Machine
# 1         Opinion   all_features_excl_penn  Stochastic Gradient Descent
# 4          Notice           pos_freq_combo                     AdaBoost
# 9          Report  all_features_excl_tfidf       Support Vector Machine
# 9          Review   all_features_excl_univ       Support Vector Machine
# 8   Advertisement   all_features_excl_univ          Logistic Regression
# 7          Notice   all_features_excl_univ           K Nearest Neighbor
# 9  LetterToEditor            pos_freq_univ       Support Vector Machine
# 2          Notice             all_features                Random Forest
# 6         Feature   all_features_excl_penn         Gaussian Naive Bayes
# 1          Speech            pos_freq_univ  Stochastic Gradient Descent
# 9          Speech   all_features_excl_penn       Support Vector Machine
# 5          Notice   all_features_excl_penn             GradientBoosting
# 8          Review            pos_freq_univ          Logistic Regression
# 1         Opinion            pos_freq_univ  Stochastic Gradient Descent
# 7          Notice  all_features_excl_tfidf           K Nearest Neighbor
# 8          Notice              line_widths          Logistic Regression
# 6    FamilyNotice            pos_freq_penn         Gaussian Naive Bayes
# 2         Fiction             all_features                Random Forest
# 2         Fiction           pos_freq_combo                Random Forest
# 2         Fiction  all_features_excl_tfidf                Random Forest
# 2         Fiction   all_features_excl_univ                Random Forest
# 7         Fiction  all_features_excl_tfidf           K Nearest Neighbor
# 2          Notice           pos_freq_combo                Random Forest
# 1         Opinion           pos_freq_combo  Stochastic Gradient Descent
# 3         Fiction  all_features_excl_tfidf                Decision Tree
# 4         Fiction            pos_freq_penn                     AdaBoost
# 7         Fiction            pos_freq_penn           K Nearest Neighbor
# 1  LetterToEditor   all_features_excl_univ  Stochastic Gradient Descent
# 9          Notice               text_stats       Support Vector Machine
# 2          Notice   all_features_excl_univ                Random Forest
# 1   Advertisement  all_features_excl_tfidf  Stochastic Gradient Descent
# 6          Speech            pos_freq_penn         Gaussian Naive Bayes
# 1  LetterToEditor            pos_freq_univ  Stochastic Gradient Descent
# 5            News             all_features             GradientBoosting
# 5          Notice            pos_freq_penn             GradientBoosting
# 5          Notice           pos_freq_combo             GradientBoosting
# 6         Opinion            pos_freq_univ         Gaussian Naive Bayes
# 1         Results            pos_freq_penn  Stochastic Gradient Descent
# 6         Feature            pos_freq_univ         Gaussian Naive Bayes
# 9  LetterToEditor            pos_freq_penn       Support Vector Machine
# 1  LetterToEditor  all_features_excl_tfidf  Stochastic Gradient Descent
# 1         Results   all_features_excl_univ  Stochastic Gradient Descent
# 8            News           pos_freq_combo          Logistic Regression
# 1  LetterToEditor   all_features_excl_penn  Stochastic Gradient Descent
# 6            News   all_features_excl_univ         Gaussian Naive Bayes
# 1  LetterToEditor           pos_freq_combo  Stochastic Gradient Descent
# 8          Speech            pos_freq_univ          Logistic Regression
# 8        Obituary  all_features_excl_tfidf          Logistic Regression
# 3          Notice            pos_freq_penn                Decision Tree
# 6            News  all_features_excl_tfidf         Gaussian Naive Bayes
# 6            News             all_features         Gaussian Naive Bayes
# 1    FamilyNotice               text_stats  Stochastic Gradient Descent
# 9          Poetry               text_stats       Support Vector Machine
# 4            News  all_features_excl_tfidf                     AdaBoost
# 4          Notice            pos_freq_penn                     AdaBoost
# 3          Notice  all_features_excl_tfidf                Decision Tree
# 1          Speech               text_stats  Stochastic Gradient Descent
# 6            News   all_features_excl_penn         Gaussian Naive Bayes
# 3          Notice   all_features_excl_univ                Decision Tree
# 9          Notice              line_widths       Support Vector Machine
# 4            News             all_features                     AdaBoost
# 1            News   all_features_excl_penn  Stochastic Gradient Descent
# 3          Notice           pos_freq_combo                Decision Tree
# 7          Notice           pos_freq_combo           K Nearest Neighbor
# 6  LetterToEditor   all_features_excl_penn         Gaussian Naive Bayes
# 2          Notice            pos_freq_penn                Random Forest
# 1          Review   all_features_excl_penn  Stochastic Gradient Descent
# 4    FamilyNotice             all_features                     AdaBoost
# 5            News  all_features_excl_tfidf             GradientBoosting
# 5            News   all_features_excl_univ             GradientBoosting
# 9          Poetry            syllable_freq       Support Vector Machine
# 7    FamilyNotice  all_features_excl_tfidf           K Nearest Neighbor
# 4            News   all_features_excl_univ                     AdaBoost
# 7    FamilyNotice   all_features_excl_univ           K Nearest Neighbor
# 1         Feature             all_features  Stochastic Gradient Descent
# 6   Advertisement  all_features_excl_tfidf         Gaussian Naive Bayes
# 8         Feature              line_widths          Logistic Regression
# 3    FamilyNotice   all_features_excl_penn                Decision Tree
# 7          Notice            pos_freq_univ           K Nearest Neighbor
# 9            News               text_stats       Support Vector Machine
# 9          Poetry              line_widths       Support Vector Machine
# 6   Advertisement   all_features_excl_univ         Gaussian Naive Bayes
# 3    FamilyNotice  all_features_excl_tfidf                Decision Tree
# 8          Notice               text_stats          Logistic Regression
# 7          Notice            pos_freq_penn           K Nearest Neighbor
# 9          Report            pos_freq_penn       Support Vector Machine
# 9          Review  all_features_excl_tfidf       Support Vector Machine
# 3    FamilyNotice   all_features_excl_univ                Decision Tree
# 9   Advertisement           pos_freq_combo       Support Vector Machine
# 8    FamilyNotice               text_stats          Logistic Regression
# 7         Opinion           pos_freq_combo           K Nearest Neighbor
# 9          Report   all_features_excl_penn       Support Vector Machine
# 1   Advertisement   all_features_excl_penn  Stochastic Gradient Descent
# 1         Feature              line_widths  Stochastic Gradient Descent
# 3          Notice             all_features                Decision Tree
# 9          Report           pos_freq_combo       Support Vector Machine
# 8         Results               text_stats          Logistic Regression
# 1          Notice              line_widths  Stochastic Gradient Descent
# 1          Notice               text_stats  Stochastic Gradient Descent
# 9   Advertisement            pos_freq_penn       Support Vector Machine
# 3          Notice   all_features_excl_penn                Decision Tree
# 8            News               text_stats          Logistic Regression
# 2         Fiction   all_features_excl_penn                Random Forest
# 7         Fiction   all_features_excl_penn           K Nearest Neighbor
# 7         Fiction   all_features_excl_univ           K Nearest Neighbor
# 2         Fiction            pos_freq_univ                Random Forest
# 5          Notice            pos_freq_univ             GradientBoosting
# 1          Poetry              line_widths  Stochastic Gradient Descent
# 3         Fiction   all_features_excl_univ                Decision Tree
# 6          Poetry           pos_freq_combo         Gaussian Naive Bayes
# 8          Poetry               text_stats          Logistic Regression
# 9   Advertisement             all_features       Support Vector Machine
# 6          Review            pos_freq_penn         Gaussian Naive Bayes
# 7         Fiction            pos_freq_univ           K Nearest Neighbor
# 9   Advertisement   all_features_excl_univ       Support Vector Machine
# 6  LetterToEditor            pos_freq_penn         Gaussian Naive Bayes
# 5            News   all_features_excl_penn             GradientBoosting
# 2    FamilyNotice             all_features                Random Forest
# 8            News            pos_freq_penn          Logistic Regression
# 3         Fiction            pos_freq_penn                Decision Tree
# 9         Feature               text_stats       Support Vector Machine
# 1   Advertisement            pos_freq_univ  Stochastic Gradient Descent
# 6    FamilyNotice               text_stats         Gaussian Naive Bayes
# 7    FamilyNotice             all_features           K Nearest Neighbor
# 8         Fiction            syllable_freq          Logistic Regression
# 6   Advertisement             all_features         Gaussian Naive Bayes
# 4    FamilyNotice  all_features_excl_tfidf                     AdaBoost
# 9         Results               text_stats       Support Vector Machine
# 2          Notice            pos_freq_univ                Random Forest
# 1         Fiction              line_widths  Stochastic Gradient Descent
# 5  LetterToEditor             all_features             GradientBoosting
# 3    FamilyNotice             all_features                Decision Tree
# 3    FamilyNotice           pos_freq_combo                Decision Tree
# 8        Obituary             all_features          Logistic Regression
# 8   Advertisement            pos_freq_univ          Logistic Regression
# 3    FamilyNotice            pos_freq_univ                Decision Tree
# 6        Obituary             all_features         Gaussian Naive Bayes
# 6          Review             all_features         Gaussian Naive Bayes
# 3    FamilyNotice            pos_freq_penn                Decision Tree
# 2          Notice   all_features_excl_penn                Random Forest
# 9  LetterToEditor               text_stats       Support Vector Machine
# 8    FamilyNotice              line_widths          Logistic Regression
# 4          Notice            pos_freq_univ                     AdaBoost
# 8          Report             all_features          Logistic Regression
# 1          Review              line_widths  Stochastic Gradient Descent
# 1         Feature   all_features_excl_penn  Stochastic Gradient Descent
# 3          Poetry            pos_freq_penn                Decision Tree
# 9            News            pos_freq_univ       Support Vector Machine
# 9         Feature              line_widths       Support Vector Machine
# 9         Opinion               text_stats       Support Vector Machine
# 9          Speech  all_features_excl_tfidf       Support Vector Machine
# 1  LetterToEditor            pos_freq_penn  Stochastic Gradient Descent
# 9          Speech   all_features_excl_univ       Support Vector Machine
# 8          Report   all_features_excl_univ          Logistic Regression
# 4            News   all_features_excl_penn                     AdaBoost
# 9          Review              line_widths       Support Vector Machine
# 7          Report             all_features           K Nearest Neighbor
# 2          Report  all_features_excl_tfidf                Random Forest
# 1            News               text_stats  Stochastic Gradient Descent
# 9   Advertisement   all_features_excl_penn       Support Vector Machine
# 6          Review           pos_freq_combo         Gaussian Naive Bayes
# 2    FamilyNotice   all_features_excl_univ                Random Forest
# 8          Report   all_features_excl_penn          Logistic Regression
# 2    FamilyNotice   all_features_excl_penn                Random Forest
# 7    FamilyNotice   all_features_excl_penn           K Nearest Neighbor
# 8        Obituary   all_features_excl_univ          Logistic Regression
# 5  LetterToEditor   all_features_excl_univ             GradientBoosting
# 2          Report             all_features                Random Forest
# 8          Report  all_features_excl_tfidf          Logistic Regression
# 4          Report             all_features                     AdaBoost
# 7          Report  all_features_excl_tfidf           K Nearest Neighbor
# 3         Fiction            pos_freq_univ                Decision Tree
# 3          Notice            pos_freq_univ                Decision Tree
# 4          Report   all_features_excl_univ                     AdaBoost
# 4          Report  all_features_excl_tfidf                     AdaBoost
# 1          Notice             line_offsets  Stochastic Gradient Descent
# 1        Obituary  all_features_excl_tfidf  Stochastic Gradient Descent
# 6            News               text_stats         Gaussian Naive Bayes
# 8          Review              line_widths          Logistic Regression
# 2          Report   all_features_excl_univ                Random Forest
# 7          Report   all_features_excl_univ           K Nearest Neighbor
# 1            News           pos_freq_combo  Stochastic Gradient Descent
# 3            News   all_features_excl_penn                Decision Tree
# 5          Report   all_features_excl_univ             GradientBoosting
# 2          Report   all_features_excl_penn                Random Forest
# 6         Results             all_features         Gaussian Naive Bayes
# 1         Feature   all_features_excl_univ  Stochastic Gradient Descent
# 6        Obituary  all_features_excl_tfidf         Gaussian Naive Bayes
# 6  LetterToEditor           pos_freq_combo         Gaussian Naive Bayes
# 2            News             all_features                Random Forest
# 1    FamilyNotice            pos_freq_penn  Stochastic Gradient Descent
# 1          Poetry            syllable_freq  Stochastic Gradient Descent
# 7         Opinion            pos_freq_penn           K Nearest Neighbor
# 1        Obituary   all_features_excl_univ  Stochastic Gradient Descent
# 6   Advertisement   all_features_excl_penn         Gaussian Naive Bayes
# 7            News  all_features_excl_tfidf           K Nearest Neighbor
# 8         Opinion              line_widths          Logistic Regression
# 6        Obituary   all_features_excl_univ         Gaussian Naive Bayes
# 6          Notice               text_stats         Gaussian Naive Bayes
# 2    FamilyNotice  all_features_excl_tfidf                Random Forest
# 9          Review               text_stats       Support Vector Machine
# 7          Report           pos_freq_combo           K Nearest Neighbor
# 5  LetterToEditor  all_features_excl_tfidf             GradientBoosting
# 4  LetterToEditor             all_features                     AdaBoost
# 4    FamilyNotice   all_features_excl_penn                     AdaBoost
# 9         Fiction             line_offsets       Support Vector Machine
# 5          Report  all_features_excl_tfidf             GradientBoosting
# 6          Review            pos_freq_univ         Gaussian Naive Bayes
# 9    FamilyNotice              line_widths       Support Vector Machine
# 2            News   all_features_excl_penn                Random Forest
# 1            News            pos_freq_penn  Stochastic Gradient Descent
# 1        Obituary            pos_freq_penn  Stochastic Gradient Descent
# 6   Advertisement           pos_freq_combo         Gaussian Naive Bayes
# 7            News   all_features_excl_univ           K Nearest Neighbor
# 5          Report             all_features             GradientBoosting
# 9          Notice            syllable_freq       Support Vector Machine
# 6          Review  all_features_excl_tfidf         Gaussian Naive Bayes
# 9          Notice             line_offsets       Support Vector Machine
# 6          Review   all_features_excl_univ         Gaussian Naive Bayes
# 7            News             all_features           K Nearest Neighbor
# 9   Advertisement            pos_freq_univ       Support Vector Machine
# 1          Review            pos_freq_univ  Stochastic Gradient Descent
# 2          Report           pos_freq_combo                Random Forest
# 3            News             all_features                Decision Tree
# 8         Opinion               text_stats          Logistic Regression
# 8          Notice             line_offsets          Logistic Regression
# 8          Speech            syllable_freq          Logistic Regression
# 7          Report            pos_freq_penn           K Nearest Neighbor
# 2            News  all_features_excl_tfidf                Random Forest
# 6            News           pos_freq_combo         Gaussian Naive Bayes
# 8            News            pos_freq_univ          Logistic Regression
# 3          Report             all_features                Decision Tree
# 6          Poetry            pos_freq_penn         Gaussian Naive Bayes
# 1          Speech              line_widths  Stochastic Gradient Descent
# 6         Results   all_features_excl_univ         Gaussian Naive Bayes
# 6         Results  all_features_excl_tfidf         Gaussian Naive Bayes
# 4  LetterToEditor  all_features_excl_tfidf                     AdaBoost
# 9          Report            pos_freq_univ       Support Vector Machine
# 4            News           pos_freq_combo                     AdaBoost
# 7          Report   all_features_excl_penn           K Nearest Neighbor
# 5          Report           pos_freq_combo             GradientBoosting
# 9         Results            syllable_freq       Support Vector Machine
# 2          Report            pos_freq_penn                Random Forest
# 2            News   all_features_excl_univ                Random Forest
# 9         Opinion              line_widths       Support Vector Machine
# 8  LetterToEditor               text_stats          Logistic Regression
# 2    FamilyNotice           pos_freq_combo                Random Forest
# 7         Opinion             all_features           K Nearest Neighbor
# 7    FamilyNotice           pos_freq_combo           K Nearest Neighbor
# 1          Report  all_features_excl_tfidf  Stochastic Gradient Descent
# 1         Results               text_stats  Stochastic Gradient Descent
# 6            News            pos_freq_penn         Gaussian Naive Bayes
# 5            News           pos_freq_combo             GradientBoosting
# 4    FamilyNotice   all_features_excl_univ                     AdaBoost
# 8         Feature               text_stats          Logistic Regression
# 1         Feature  all_features_excl_tfidf  Stochastic Gradient Descent
# 7            News   all_features_excl_penn           K Nearest Neighbor
# 3            News  all_features_excl_tfidf                Decision Tree
# 6          Report  all_features_excl_tfidf         Gaussian Naive Bayes
# 9          Speech            syllable_freq       Support Vector Machine
# 6          Report   all_features_excl_univ         Gaussian Naive Bayes
# 5          Report   all_features_excl_penn             GradientBoosting
# 1    FamilyNotice              line_widths  Stochastic Gradient Descent
# 6         Results            pos_freq_univ         Gaussian Naive Bayes
# 9          Poetry             all_features       Support Vector Machine
# 4          Poetry  all_features_excl_tfidf                     AdaBoost
# 4          Poetry   all_features_excl_univ                     AdaBoost
# 4          Poetry   all_features_excl_penn                     AdaBoost
# 9          Poetry   all_features_excl_penn       Support Vector Machine
# 9          Poetry   all_features_excl_univ       Support Vector Machine
# 9          Poetry  all_features_excl_tfidf       Support Vector Machine
# 4          Poetry             all_features                     AdaBoost
# 1          Speech            pos_freq_penn  Stochastic Gradient Descent
# 1          Report   all_features_excl_univ  Stochastic Gradient Descent
# 1          Review           pos_freq_combo  Stochastic Gradient Descent
# 5          Report            pos_freq_penn             GradientBoosting
# 3          Poetry           pos_freq_combo                Decision Tree
# 4          Report           pos_freq_combo                     AdaBoost
# 6         Results   all_features_excl_penn         Gaussian Naive Bayes
# 8          Speech              line_widths          Logistic Regression
# 9          Poetry           pos_freq_combo       Support Vector Machine
# 9    FamilyNotice            syllable_freq       Support Vector Machine
# 3          Report           pos_freq_combo                Decision Tree
# 6          Report            pos_freq_penn         Gaussian Naive Bayes
# 6          Report             all_features         Gaussian Naive Bayes
# 9          Poetry            pos_freq_penn       Support Vector Machine
# 7         Opinion  all_features_excl_tfidf           K Nearest Neighbor
# 8    FamilyNotice                   tf_idf          Logistic Regression
# 8         Results            syllable_freq          Logistic Regression
# 4          Report   all_features_excl_penn                     AdaBoost
# 4          Report            pos_freq_penn                     AdaBoost
# 6          Review   all_features_excl_penn         Gaussian Naive Bayes
# 9          Poetry            pos_freq_univ       Support Vector Machine
# 3            News           pos_freq_combo                Decision Tree
# 2    FamilyNotice            pos_freq_penn                Random Forest
# 5  LetterToEditor   all_features_excl_penn             GradientBoosting
# 6  LetterToEditor            pos_freq_univ         Gaussian Naive Bayes
# 9            News              line_widths       Support Vector Machine
# 9          Speech                   tf_idf       Support Vector Machine
# 7         Opinion   all_features_excl_univ           K Nearest Neighbor
# 3         Opinion             all_features                Decision Tree
# 1   Advertisement           pos_freq_combo  Stochastic Gradient Descent
# 8         Opinion             line_offsets          Logistic Regression
# 4            News            pos_freq_penn                     AdaBoost
# 6        Obituary   all_features_excl_penn         Gaussian Naive Bayes
# 6         Results           pos_freq_combo         Gaussian Naive Bayes
# 3          Report  all_features_excl_tfidf                Decision Tree
# 1    FamilyNotice                   tf_idf  Stochastic Gradient Descent
# 9    FamilyNotice                   tf_idf       Support Vector Machine
# 4    FamilyNotice           pos_freq_combo                     AdaBoost
# 3  LetterToEditor  all_features_excl_tfidf                Decision Tree
# 5            News            pos_freq_penn             GradientBoosting
# 6          Report           pos_freq_combo         Gaussian Naive Bayes
# 3         Opinion           pos_freq_combo                Decision Tree
# 3          Speech            pos_freq_penn                Decision Tree
# 4         Opinion   all_features_excl_univ                     AdaBoost
# 4         Opinion             all_features                     AdaBoost
# 9        Obituary            pos_freq_univ       Support Vector Machine
# 9         Opinion             line_offsets       Support Vector Machine
# 6          Poetry            pos_freq_univ         Gaussian Naive Bayes
# 3            News   all_features_excl_univ                Decision Tree
# 3          Report   all_features_excl_univ                Decision Tree
# 9         Feature            syllable_freq       Support Vector Machine
# 9         Opinion            syllable_freq       Support Vector Machine
# 4         Opinion  all_features_excl_tfidf                     AdaBoost
# 6          Report   all_features_excl_penn         Gaussian Naive Bayes
# 3  LetterToEditor             all_features                Decision Tree
# 4  LetterToEditor   all_features_excl_univ                     AdaBoost
# 9            News            syllable_freq       Support Vector Machine
# 3          Report   all_features_excl_penn                Decision Tree
# 8          Report           pos_freq_combo          Logistic Regression
# 2         Opinion  all_features_excl_tfidf                Random Forest
# 7            News           pos_freq_combo           K Nearest Neighbor
# 5         Opinion   all_features_excl_univ             GradientBoosting
# 6         Results            pos_freq_penn         Gaussian Naive Bayes
# 1         Opinion             line_offsets  Stochastic Gradient Descent
# 9          Report               text_stats       Support Vector Machine
# 8         Feature            syllable_freq          Logistic Regression
# 9          Speech              line_widths       Support Vector Machine
# 5         Opinion           pos_freq_combo             GradientBoosting
# 5         Opinion  all_features_excl_tfidf             GradientBoosting
# 8         Fiction             line_offsets          Logistic Regression
# 1            News            pos_freq_univ  Stochastic Gradient Descent
# 3  LetterToEditor   all_features_excl_univ                Decision Tree
# 1          Speech            syllable_freq  Stochastic Gradient Descent
# 7    FamilyNotice            pos_freq_univ           K Nearest Neighbor
# 8          Report            pos_freq_penn          Logistic Regression
# 3         Opinion  all_features_excl_tfidf                Decision Tree
# 1          Report             all_features  Stochastic Gradient Descent
# 7  LetterToEditor  all_features_excl_tfidf           K Nearest Neighbor
# 9          Report              line_widths       Support Vector Machine
# 3         Opinion   all_features_excl_univ                Decision Tree
# ...
# 0       0.860795               0            0           0         0.5
# 6       0.860795               0            0           0         0.5
# 7       0.981061               0            0           0         0.5
# 6       0.981061               0            0           0         0.5
# 5       0.981061               0            0           0         0.5
# 0       0.981061               0            0           0         0.5
# 0       0.860795               0            0           0         0.5
# 0       0.860795               0            0           0         0.5
# 6       0.860795               0            0           0         0.5
# 0       0.860795               0            0           0         0.5
# 1       0.860795               0            0           0         0.5
# 4       0.860795               0            0           0         0.5
# 7       0.981061               0            0           0         0.5
# 6       0.981061               0            0           0         0.5
# 5       0.981061               0            0           0         0.5
# 4       0.981061               0            0           0         0.5
# 0       0.981061               0            0           0         0.5
# 5       0.860795               0            0           0         0.5
# 0       0.980114               0            0           0         0.5
# 6       0.958333               0            0           0         0.5
# 0       0.980114               0            0           0         0.5
# 5       0.980114               0            0           0         0.5
# 6       0.950758               0            0           0         0.5
# 4       0.980114               0            0           0         0.5
# 0       0.950758               0            0           0         0.5
# 5       0.950758               0            0           0         0.5
# 6       0.980114               0            0           0         0.5
# 0       0.980114               0            0           0         0.5
# 6       0.950758               0            0           0         0.5
# 0       0.950758               0            0           0         0.5
# 4       0.950758               0            0           0         0.5
# 5       0.950758               0            0           0         0.5
# 0       0.950758               0            0           0         0.5
# 0       0.950758               0            0           0         0.5
# 0       0.980114               0            0           0         0.5
# 4       0.950758               0            0           0         0.5
# 0       0.715909               0            0           0         0.5
# 0       0.838068               0            0           0         0.5
# 0       0.950758               0            0           0         0.5
# 7       0.980114               0            0           0         0.5
# 6       0.980114               0            0           0         0.5
# 5       0.980114               0            0           0         0.5
# 0       0.980114               0            0           0         0.5
# 5       0.980114               0            0           0         0.5
# 0       0.980114               0            0           0         0.5
# 5       0.980114               0            0           0         0.5
# 0       0.980114               0            0           0         0.5
# 0       0.836174               0            0           0         0.5
# 5       0.950758               0            0           0         0.5
# 0       0.980114               0            0           0         0.5
# 0       0.980114               0            0           0         0.5
# 6       0.950758               0            0           0         0.5
# 5       0.980114               0            0           0         0.5
# 0       0.980114               0            0           0         0.5
# 0       0.715909               0            0           0         0.5
# 0       0.950758               0            0           0         0.5
# 4       0.950758               0            0           0         0.5
# 5       0.980114               0            0           0         0.5
# 6       0.950758               0            0           0         0.5
# 0       0.980114               0            0           0         0.5
# 0       0.950758               0            0           0         0.5
# 0       0.950758               0            0           0         0.5
# 7       0.980114               0            0           0         0.5
# 6       0.980114               0            0           0         0.5
# 0       0.715909               0            0           0         0.5
# 0       0.950758               0            0           0         0.5
# 0       0.950758               0            0           0         0.5
# 0       0.715909               0            0           0         0.5
# 0       0.838068               0            0           0         0.5
# 5       0.980114               0            0           0         0.5
# 3       0.939394       0.0285714    0.0322581    0.030303    0.499544
# 4       0.991477               0            0           0    0.499523
# 5       0.991477               0            0           0    0.499523
# 6       0.991477               0            0           0    0.499523
# 5       0.991477               0            0           0    0.499523
# 5       0.989583               0            0           0    0.499522
# 5       0.989583               0            0           0    0.499522
# 2       0.989583               0            0           0    0.499522
# 5       0.989583               0            0           0    0.499522
# 5       0.989583               0            0           0    0.499522
# 7       0.989583               0            0           0    0.499522
# 5       0.989583               0            0           0    0.499522
# 4       0.989583               0            0           0    0.499522
# 4       0.989583               0            0           0    0.499522
# 5       0.989583               0            0           0    0.499522
# 4       0.989583               0            0           0    0.499522
# 5       0.989583               0            0           0    0.499522
# 4       0.989583               0            0           0    0.499522
# 4       0.989583               0            0           0    0.499522
# 4       0.989583               0            0           0    0.499522
# 5       0.980114               0            0           0    0.499517
# 2       0.980114               0            0           0    0.499517
# 4       0.980114               0            0           0    0.499517
# 4       0.980114               0            0           0    0.499517
# 2       0.980114               0            0           0    0.499517
# 4       0.980114               0            0           0    0.499517
# 5       0.980114               0            0           0    0.499517
# 2       0.980114               0            0           0    0.499517
# 2       0.980114               0            0           0    0.499517
# 7       0.980114               0            0           0    0.499517
# 2       0.980114               0            0           0    0.499517
# 5       0.980114               0            0           0    0.499517
# 7       0.980114               0            0           0    0.499517
# 4       0.979167               0            0           0    0.499517
# 4       0.979167               0            0           0    0.499517
# 4       0.979167               0            0           0    0.499517
# 2       0.979167               0            0           0    0.499517
# 5       0.969697               0            0           0    0.499512
# 4       0.969697               0            0           0    0.499512
# 2       0.969697               0            0           0    0.499512
# 7       0.957386               0            0           0    0.499506
# 4       0.957386               0            0           0    0.499506
# 4       0.951705               0            0           0    0.499503
# 4       0.951705               0            0           0    0.499503
# 5       0.951705               0            0           0    0.499503
# 4       0.949811               0            0           0    0.499502
# 3        0.99053               0            0           0    0.499046
# 5        0.99053               0            0           0    0.499046
# 4        0.99053               0            0           0    0.499046
# 7       0.988636               0            0           0    0.499044
# 7       0.988636               0            0           0    0.499044
# 4       0.988636               0            0           0    0.499044
# 4       0.988636               0            0           0    0.499044
# 6       0.988636               0            0           0    0.499044
# 4       0.988636               0            0           0    0.499044
# 3       0.988636               0            0           0    0.499044
# 5       0.979167               0            0           0    0.499035
# 7       0.979167               0            0           0    0.499035
# 1       0.979167               0            0           0    0.499035
# 7       0.979167               0            0           0    0.499035
# 4       0.979167               0            0           0    0.499035
# 1       0.979167               0            0           0    0.499035
# 4       0.979167               0            0           0    0.499035
# 7        0.97822               0            0           0    0.499034
# 5        0.97822               0            0           0    0.499034
# 4       0.956439               0            0           0    0.499012
# 2       0.950758               0            0           0    0.499006
# 2       0.717803        0.162162      0.17341    0.167598    0.498936
# 3       0.717803        0.162162      0.17341    0.167598    0.498936
# 4       0.858902               0            0           0      0.4989
# 5       0.858902               0            0           0      0.4989
# 3       0.989583               0            0           0    0.498569
# 2       0.989583               0            0           0    0.498569
# 5       0.989583               0            0           0    0.498569
# 5       0.989583               0            0           0    0.498569
# 4        0.97822               0            0           0    0.498552
# 7       0.977273               0            0           0    0.498551
# 2       0.977273               0            0           0    0.498551
# 7       0.967803               0            0           0    0.498537
# 4       0.967803               0            0           0    0.498537
# 2       0.955492               0            0           0    0.498518
# 5       0.955492               0            0           0    0.498518
# 7       0.955492               0            0           0    0.498518
# 7       0.955492               0            0           0    0.498518
# 4       0.857955               0            0           0     0.49835
# 4       0.833333               0            0           0    0.498301
# 3       0.988636               0            0           0    0.498092
# 4       0.988636               0            0           0    0.498092
# 5       0.986742               0            0           0    0.498088
# 4       0.977273               0            0           0    0.498069
# 7       0.977273               0            0           0    0.498069
# 4       0.966856               0            0           0    0.498049
# 5       0.954545               0            0           0    0.498024
# 7        0.94697               0            0           0    0.498008
# 2       0.947917               0            0           0    0.497515
# 7       0.947917               0            0           0    0.497515
# 3       0.986742               0            0           0    0.497137
# 4       0.984848               0            0           0    0.497132
# 3       0.984848               0            0           0    0.497132
# 5       0.975379               0            0           0    0.497104
# 2       0.952652               0            0           0    0.497036
# 2       0.952652               0            0           0    0.497036
# 2       0.945076               0            0           0    0.497012
# 3       0.985795               0            0           0     0.49666
# 3       0.983902               0            0           0    0.496654
# 6       0.974432               0            0           0    0.496622
# 3       0.982955               0            0           0    0.496176
# 5       0.973485               0            0           0    0.496139
# 3       0.972538               0            0           0    0.495656
# 3       0.982955               0            0           0    0.495229
# 5       0.981061               0            0           0     0.49522
# 5       0.981061               0            0           0     0.49522
# 3       0.981061               0            0           0     0.49522
# 3       0.981061               0            0           0     0.49522
# 2       0.981061               0            0           0     0.49522
# 3       0.971591               0            0           0    0.495174
# 7       0.942235               0            0           0    0.494533
# 2       0.940341               0            0           0    0.494522
# 3       0.979167               0            0           0    0.494264
# 3       0.979167               0            0           0    0.494264
# 3       0.977273               0            0           0    0.493308
# 2       0.977273               0            0           0    0.493308
# 3       0.966856               0            0           0    0.492761
# 6       0.973485               0            0           0    0.491396
# 3       0.920455       0.0238095    0.0227273   0.0232558    0.491107
# 3       0.963068               0            0           0     0.49083
# 2       0.963068               0            0           0     0.49083
# 3       0.963068               0            0           0     0.49083
# 3       0.960227               0            0           0    0.489855
# 2       0.960227               0            0           0    0.489855
# 3       0.958333               0            0           0    0.488417
# 8       0.535038        0.155844     0.416185    0.226772    0.487254
# 2       0.954545               0            0           0    0.486486
# 3       0.954545               0            0           0    0.486486
# 1       0.807765       0.0757576    0.0340136   0.0469484    0.483453
# 1       0.895833        0.010989     0.047619   0.0178571    0.480331
# 8       0.566288        0.044843     0.384615   0.0803213    0.480156
# 2       0.746212        0.104575     0.108844    0.106667    0.479064
# 3       0.746212        0.104575     0.108844    0.106667    0.479064
# 9       0.723485       0.0338346     0.204545   0.0580645    0.475296
# 1       0.217803       0.0389151         0.75    0.073991    0.472332
# 1       0.934659               0            0           0    0.471797
# 8       0.563447       0.0356347     0.363636   0.0649087    0.467885
# 1       0.573864        0.230216     0.213333    0.221453    0.465132
# 1       0.620265       0.0152672          0.3   0.0290557    0.463224
# 1        0.52178      0.00795229          0.4   0.0155945    0.461472
# 1       0.714962       0.0337079     0.173077   0.0564263    0.458052
# 8       0.557765       0.0151844         0.35    0.029106    0.455888
# 1        0.89678               0            0           0    0.451813
# 8       0.549242       0.0148936         0.35   0.0285714    0.451544
# 1       0.428977      0.00500835          0.3  0.00985222    0.365105
# 8       0.447917      0.00345423         0.25  0.00681431    0.349714

# %%
# Export the dataframe of results to a CSV file 
results_df.to_csv("20220126_PP_3518articles_metrics.csv")
